# %%
from python_scripts.connector import *
from python_scripts.helper import *
from python_scripts.export_images import export_images
# Out:
# Succefully connected!

# %%
from eval_scripts.evalscript_ndvi_labels  import *

# %%
coords = [86.773796,21.848934,87.231445,22.063497]

# %%
labels = simple_request(evalscript_nvdi_labels, coords, config)

# %%
labels[0].dtype
# Out:
# dtype('float32')

# %%
# Preprocessing 
import numpy as np

# %%
THRESHOLD = 0.5

def get_fc(ndvi):

    ndvi_copy = ndvi.copy()

    vegetation = np.where(ndvi_copy > THRESHOLD, 1, 0)
    return vegetation

# %%
ndvi_labels= get_fc(labels) # labels/ targets

# %%
ndvi_labels.shape
# Out:
# (512, 512)

# %%
# get our features satellite imagery
from eval_scripts.evalscript_ndvi import *

# %%
img_ndvi = simple_request(evalscript_ndvi, coords, config)

# %%
plot_image(img_nvdi)

# %%
img_ndvi.shape
# Out:
# (512, 512, 3)
